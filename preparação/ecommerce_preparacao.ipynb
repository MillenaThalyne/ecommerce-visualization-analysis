# %% [markdown]
# # Análise de Visualização de Comércio Eletrônico (Ecommerce)
# - Para essa segunda etapa do projeto, irei realizar a Normalização dos dados e Engenharia de Features:
#   - Campos adicionas de escala, utilizando o MinMaxScaler;
#   - Campo de frequência para Material.

# %% [markdown]
# ## 1.0 Bibliotecas e Leitura de Dados 📋

# %%
# Bibliotecas utilizadas
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
# Leitura de base de dados tratados
df = pd.read_csv('ecommerce_tratado.csv')
df.head()
# Out:
#                                               Título  Nota  N_Avaliações  \
# 0  Pijama Cirurgico  Scrub Roupa Privativa Hospit...   4.0         273.0
# 1  Kit 10 Cuecas Boxer Lupo Cueca Box Algodão Mas...   4.5        3034.0
# 2  Kit Com 10 Cuecas Boxer Algodão Sem Costura Zo...   4.7        5682.0
# 3  Kit 10 Cuecas Boxer Mash Algodão Cotton Box Or...   4.6        1700.0
# 4  Kit 3 Short Jeans Feminino Cintura Alta Barato...   4.4         507.0
#
#    Desconto                            Marca   Material      Gênero  \
# 0       0.0  toronto uniformes profissionais  poliéster  Sem gênero
# 1      18.0                             lupo    algodão   Masculino
# 2      20.0                            zorba    algodão   Masculino
# 3      22.0                             mash    algodão   Masculino
# 4       9.0                     menina linda       jean    Feminino
#
#          Temporada                                            Review1  \
# 0     não definido  Preço justo , bem feito acabamento ok. Única s...
# 1   outono/inverno  As cuecas são boas; porém você percebe na cost...
# 2     não definido  O tecido é bom e são confortáveis. Só que a nu...
# 3  primavera/verão  As cuecas são boas, porém meu marido usa g e p...
# 4  primavera/verão  Estou encantada com essas peças!.\nOs shorts s...
#
#                                              Review2  \
# 0  Tamanho bom, costuras de qualidade, porém teci...
# 1  Pelo preço promocional, com ctz tem algum defe...
# 2  Vendo comentários de outros consumidores vejo ...
# 3  E o tamanho certo, mas em baixo dela, fica mui...
# 4       Recomendo, tecido confortável, igual a foto.
#
#                                              Review3  Qtd_Vendidos   Preço  \
# 0  Muito bom, só poderia ter os cortes na lateral...          1000   69.90
# 1  Serviram muito bem, porém é nítido que o pano ...         10000  232.89
# 2  Produto não é nem de longe original, tecido gr...         50000  199.90
# 3  Produto não parece.\nOriginal e veio 2 modelos...         10000  229.39
# 4  Gostei muito dos shorts, material bom, para us...          1000  129.20
#
#    Marca_Cod  Material_Cod  Temporada_Cod  Marca_Freq
# 0        781           122              1    0.002274
# 1        463            25              3    0.042292
# 2        838            25              1    0.009095
# 3        494            25              7    0.010914
# 4        509            74              7    0.010005

# %% [markdown]
# ## 2.0 Normalização 🎲

# %% [markdown]
# ### 2.1 Marca, Material, Gênero e Temporada
# - Normalização de campos de texto a fim de deixar os registros de nomes com a primeira letra em maiúsculo.

# %%
# Atualizando registros com a primeira letra em maiúsculo
df['Marca'] = df['Marca'].str.title()
df['Material'] = df['Material'].str.title()
df['Temporada'] = df['Temporada'].str.title()
df['Gênero'] = df['Gênero'].str.title()

# %%
# Visualização
df[['Marca', 'Material', 'Temporada', 'Gênero']].drop_duplicates()
# Out:
#                                 Marca              Material        Temporada  \
# 0     Toronto Uniformes Profissionais             Poliéster     Não Definido
# 1                                Lupo               Algodão   Outono/Inverno
# 2                               Zorba               Algodão     Não Definido
# 3                                Mash               Algodão  Primavera/Verão
# 4                        Menina Linda                  Jean  Primavera/Verão
# ...                               ...                   ...              ...
# 1755        Feminina Academia Atacado             Poliéster  Primavera/Verão
# 1757                           Levi'S  Algodão Com Elastano   Outono/Inverno
# 1759                           Destaq               Algodão     Não Definido
# 1760                      Inoffensive         Indeterminado     Não Definido
# 1761                Balão Magico Kids         Indeterminado     Não Definido
#
#                    Gênero
# 0              Sem Gênero
# 1               Masculino
# 2               Masculino
# 3               Masculino
# 4                Feminino
# ...                   ...
# 1755             Feminino
# 1757            Masculino
# 1759  Sem Gênero Infantil
# 1760             Feminino
# 1761                Bebês
#
# [1066 rows x 4 columns]

# %% [markdown]
# ### 2.2 MinMaxScaler
# - Como mencionado na etapa anterior, irei realizar novamente o processo de criação dos campos utilizando o MinMaxScaler, pois as variáveis originais tiveram alteração de tratamento e, por isso, ele tipo de trabalho deveria ser realizado novamente;
# - Com isso, será criada escalas para Nota, N_Avaliações, Desconto e Preço, a fim de fazer visualizações interessantes na próxima etapa.

# %%
# Chamando a classe do Scaler
minmax = MinMaxScaler()

# Criando variáveis com o Scaler
df['Nota_MinMax'] = minmax.fit_transform(df[['Nota']])
df['N_Avaliações_MinMax'] = minmax.fit_transform(df[['N_Avaliações']])
df['Desconto_MinMax'] = minmax.fit_transform(df[['Desconto']])
df['Preço_MinMax'] = minmax.fit_transform(df[['Preço']])

# %% [markdown]
# ## 3.0 Engenharia de Features 🎲

# %% [markdown]
# ### 3.1 Frequência
# - Na última etapa, eu tive que fazer a exclusão do campo ‘Material_Freq’, pois precisei fazer tratamento da variável original Material (o que não foi necessário para ‘Marca_Freq’);
# - Por causa disso, nessa etapa irei refazer esse campo a fim de ter-se mais uma informação interessante para este projeto.

# %%
# Adicionando variável para frequência de Material
material_freq = df['Material'].value_counts() / len(df)
df['Material_Freq'] = df['Material'].map(material_freq)

# %% [markdown]
# ## 4.0 Salvando Dados Preparados 🎲

# %%
# Informações Adicionadas
print('Quantidade de Linhas:', df.shape[0])
print('Quantidade de Colunas:', df.shape[1])
print('Adição dos Campos:\n{}'.format(df[['Nota_MinMax', 'N_Avaliações_MinMax', 'Desconto_MinMax', 'Preço_MinMax', 'Material_Freq']].columns.to_list()))
# Out:
# Quantidade de Linhas: 1763
# Quantidade de Colunas: 22
# Adição dos Campos:
# ['Nota_MinMax', 'N_Avaliações_MinMax', 'Desconto_MinMax', 'Preço_MinMax', 'Material_Freq']

# %%
df.to_csv('ecommerce_preparados.csv', index=False)
